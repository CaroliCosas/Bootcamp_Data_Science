# %% [markdown]
# <a href="https://colab.research.google.com/github/CaroliCosas/Bootcamp_Data_Science/blob/main/Mod2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from collections import Counter

# %%
# Cargar datos
def cargar_datos(filepath):
    price = np.genfromtxt(filepath, usecols=(0),delimiter=",", dtype=None, encoding="utf-8", skip_header=1)
    baths = np.genfromtxt(filepath, usecols=(1),delimiter=",", dtype=None, encoding="utf-8", skip_header=1)
    rooms = np.genfromtxt(filepath, usecols=(2),delimiter=",", dtype=None, encoding="utf-8", skip_header=1)
    m2 = np.genfromtxt(filepath, usecols=(3), delimiter=",", dtype=None, encoding="utf-8", skip_header=1)
    addresses = np.genfromtxt(filepath, usecols=(4), delimiter=",", dtype=None, encoding="utf-8", skip_header=1)

    return price, baths, rooms, m2, addresses

# %%
# Estadística básica
def estadistica_basica(price):
    mean_price = round(np.mean(price), 4)
    median_price = round(np.median(price), 4)
    max_price = np.max(price)
    min_price = np.min(price)
    print("Estadística básica sobre precios:")
    print(f"Media: {mean_price} €, Mediana: {median_price} €, Máximo: {max_price} €, Mínimo: {min_price} €")

# %%
# Histograma y curva de densidad
def histograma_curva_densidad(price):
    print("Histograma y Curva de Densidad de Precios")
    plt.figure(figsize=(10, 6))
    sns.histplot(price, kde=True, bins=30, color="blue", alpha=0.6)
    plt.title("Histograma y Curva de Densidad de Precios")
    plt.xlabel("Precio (€)")
    plt.ylabel("Frecuencia del precio")
    plt.grid()
    plt.show()

# %%
# Cuartiles e IQR
def cuartiles_iqr(price):
    q1 = np.percentile(price, 25)
    q2 = np.percentile(price, 50)
    q3 = np.percentile(price, 75)
    iqr = q3 - q1
    print("Cuartiles e IQR:")
    print(f"Q1: {q1}, Q2 (mediana): {q2}, Q3: {q3}")
    print(f"IQR: {iqr}")
    return q1, q3, iqr

# %%
# Filtrar por porcentaje
def filtrar_por_porcentaje(price):
    price_sorted = np.sort(price)
    # Calcular los percentiles
    bottom_20_percent = np.percentile(price_sorted, 20)
    top_20_percent = np.percentile(price_sorted, 80)
    
    # Filtrar precios según los percentiles
    bottom_prices = price[price <= bottom_20_percent]
    top_prices = price[price >= top_20_percent]

    # Imprimir resultados
    print("Filtrar por porcentaje:")
    print(f"Percentil 20: {bottom_20_percent:.2f}")
    print(f"Percentil 80: {top_20_percent:.2f}")
    print(f"Cantidad en el 20% más barato: {len(bottom_prices)}")
    print(f"Cantidad en el 20% más caro: {len(top_prices)}")
   
    return top_prices, bottom_prices, top_20_percent, bottom_20_percent

# %%
def filtrar_barrios_baratos(price, addresses):
    # Crear un diccionario para agrupar precios por barrio
    barrios = {}
    for precio, barrio in zip(price, addresses):
        if barrio not in barrios:
            barrios[barrio] = []
        barrios[barrio].append(precio)

    # Calcular el percentil 20 para cada barrio
    barrios_baratos = {}
    for barrio, precios in barrios.items():
        percentil_20 = np.percentile(precios, 20)
        precios_baratos = [p for p in precios if p <= percentil_20]
        barrios_baratos[barrio] = {
            "percentil_20": percentil_20,
            "precios_baratos": precios_baratos,
            "num_casas_baratas": len(precios_baratos)
        }

    # Mostrar resultados
    print(f"Número total de barrios analizados: {len(barrios_baratos)}")
    print("Barrios con precios en el 20% más baratos:")
    for barrio, info in barrios_baratos.items():
        print(f"- {barrio}:")
        print(f"  Percentil 20: {info['percentil_20']:.2f}")
        print(f"  Número de casas baratas: {info['num_casas_baratas']}")
        print(f"  Precios más baratos: {info['precios_baratos']}")

    return barrios_baratos

# %%
def visualizar_barrios(barrios_baratos):
    # Extraer datos para la visualización
    barrios = list(barrios_baratos.keys())
    num_casas_baratas = [info["num_casas_baratas"] for info in barrios_baratos.values()]
    
    # Crear un gráfico de barras
    plt.figure(figsize=(10, 6))
    plt.bar(barrios, num_casas_baratas, color='skyblue', edgecolor='black')
    plt.title("Número de casas baratas por barrio (20% más barato)")
    plt.xlabel("Barrios")
    plt.ylabel("Número de casas baratas")
    plt.xticks(rotation=45, ha="right")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Visualizar resultados
visualizar_barrios(barrios_baratos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 18
#      15     plt.show()
#      17 # Visualizar resultados
# ---> 18 visualizar_barrios(barrios_baratos)
#
# NameError: name 'barrios_baratos' is not defined

# %%
# Moda
def moda(addresses):
    address_mode = Counter(addresses).most_common(1)
    print(f"Moda de las direcciones: {address_mode}")

# %%
# Varianza y desviación estándar
def varianza_desviacion(price):
    variance = np.var(price)
    std_dev = np.std(price)
    print(f"Varianza: {variance}, Desviación estándar: {std_dev}")
    return variance, std_dev

# %%
# Detectar outliers con Tukey
def filtro_outliers_tukey(price, q1, q3, iqr):
    upper_limit = q3 + 1.5 * iqr
    lower_limit = q1 - 1.5 * iqr
    outliers = price[(price > upper_limit) | (price < lower_limit)]
    print(f"Outliers detectados con Tukey: {len(outliers)}")
    return upper_limit, lower_limit, outliers

# %%
# Graficar outliers
def graficar_outliers(price, upper_limit, lower_limit):
    plt.figure(figsize=(10, 6))
    sns.histplot(price, bins=30, color="blue", alpha=0.6, kde=True)
    plt.axvline(upper_limit, color='red', linestyle='dashed', linewidth=1, label="Límite Superior")
    plt.axvline(lower_limit, color='blue', linestyle='dashed', linewidth=1, label="Límite Inferior")
    plt.legend()
    plt.title("Outliers con límites marcados")
    plt.grid()
    plt.show()

# %%
# Matriz de correlación
def matriz_correlacion(price, bedrooms, bathrooms, m2):
    data_matrix = np.corrcoef([price, bedrooms, bathrooms, m2])
    sns.heatmap(data_matrix, annot=True, xticklabels=["price", "bedrooms", "bathrooms", "m2"], yticklabels=["price", "bedrooms", "bathrooms", "m2"])
    plt.title("Matriz de Correlación")
    plt.show()

# %%
# Estandarizar
def estandarizar(price):
    mean_price = np.mean(price)
    std_dev_price = np.std(price)
    price_std = (price - mean_price) / std_dev_price
    return price_std

# %%
# Asimetría y curtosis
def asimetria_curtosis(price):
    skewness = stats.skew(price)
    kurtosis = stats.kurtosis(price)
    print(f"Asimetría: {skewness}, Curtosis: {kurtosis}")

# %%
# Transformar distribuciones
def transformar_distribuciones(price):
    price_log = np.log(price[price > 0])
    plt.figure(figsize=(10, 6))
    sns.histplot(price_log, kde=True, bins=30, color="green", alpha=0.6)
    plt.title("Transformación Logarítmica de Precios")
    plt.xlabel("Log(Precio)")
    plt.ylabel("Frecuencia")
    plt.grid()
    plt.show()

# %%
# Contraste de hipótesis
def contraste_hipotesis_barrio(price, addresses, barrio_x, barrio_y):
    barrio_x_prices = price[addresses == barrio_x]
    barrio_y_prices = price[addresses == barrio_y]
    t_stat, p_value = stats.ttest_ind(barrio_x_prices, barrio_y_prices, equal_var=False)
    print(f"T-stat: {t_stat}, P-value: {p_value}")

def contraste_hipotesis_baños(price, bathrooms):
    three_bathrooms = price[bathrooms >= 3]
    one_two_bathrooms = price[(bathrooms == 1) | (bathrooms == 2)]
    t_stat, p_value = stats.ttest_ind(three_bathrooms, one_two_bathrooms, equal_var=False)
    print(f"T-stat: {t_stat}, P-value: {p_value}")

# %%
# Carga del archivo y ejecución de análisis
filepath = "../Data/idealista_madrid.csv" 
price, baths, rooms, m2, addresses = cargar_datos(filepath)
# Verificar los datos cargados
print("Primeros 10 Precios:", price[:10])  # Primeros 10 precios
print("Primeros 10 número de Baños:", baths[:10])    # Primeros 10 valores de baños
print("Primeros 10 número de Habitaciones:", rooms[:10])  # Primeros 10 valores de habitaciones
print("Primeros 10 Metros cuadrados:", m2[:10])  # Primeros 10 valores de tamaño
print("Primeros 10 Barrios:", addresses[:10])  # Primeros 10 valores de direcciones
print("------------------------------------------------")

estadistica_basica(price)
print("------------------------------------------------")

histograma_curva_densidad(price)
print("------------------------------------------------")

q1, q3, iqr = cuartiles_iqr(price)
print("------------------------------------------------")

filtrar_por_porcentaje(price)
print("------------------------------------------------")

filtrar_barrios_baratos(price, addresses)
print("------------------------------------------------")

moda(addresses)
print("------------------------------------------------")

variance, std_dev = varianza_desviacion(price)
print("------------------------------------------------")

upper_limit, lower_limit, outliers = filtro_outliers_tukey(price, q1, q3, iqr)
print("------------------------------------------------")

graficar_outliers(price, upper_limit, lower_limit)
print("------------------------------------------------")

matriz_correlacion(price, baths, rooms, m2)
print("------------------------------------------------")

price_std = estandarizar(price)
print("------------------------------------------------")

asimetria_curtosis(price)
print("------------------------------------------------")

transformar_distribuciones(price)
print("------------------------------------------------")

plt.boxplot(price, showmeans=True)
# Out:
# Primeros 10 Precios: [1920000 1995000 1300000 1650000 1590750 1590000 5700000 2190000 1190000
#   675000]
# Primeros 10 número de Baños: [3 3 3 3 3 4 5 4 2 2]
# Primeros 10 número de Habitaciones: [3 3 4 3 3 5 4 4 2 3]
# Primeros 10 Metros cuadrados: [183 170 270 248 116 360 305 183 112 153]
# Primeros 10 Barrios: ['Recoletos' 'Castellana' 'Hortaleza' 'Chamartín' 'Recoletos'
#  'Cuatro Caminos' 'Recoletos' 'Goya' 'Goya' 'Aravaca']
# ------------------------------------------------
# Estadística básica sobre precios:
# Media: 1290575.2623 €, Mediana: 990000.0 €, Máximo: 8900000 €, Mínimo: 122000 €
# ------------------------------------------------
# Histograma y Curva de Densidad de Precios
# ------------------------------------------------
# Cuartiles e IQR:
# Q1: 625000.0, Q2 (mediana): 990000.0, Q3: 1650000.0
# IQR: 1025000.0
# ------------------------------------------------
# Filtrar por porcentaje:
# Percentil 20: 529900.00
# Percentil 80: 1850000.00
# Cantidad en el 20% más barato: 184
# Cantidad en el 20% más caro: 185
# ------------------------------------------------
# Número total de barrios analizados: 105
# Barrios con precios en el 20% más baratos:
# - Recoletos:
#   Percentil 20: 1300000.00
#   Número de casas baratas: 5
#   Precios más baratos: [np.int64(1300000), np.int64(1300000), np.int64(1200000), np.int64(990000), np.int64(730000)]
# - Castellana:
#   Percentil 20: 1104000.00
#   Número de casas baratas: 4
#   Precios más baratos: [np.int64(485000), np.int64(879000), np.int64(960000), np.int64(780000)]
# - Hortaleza:
#   Percentil 20: 874000.00
#   Número de casas baratas: 12
#   Precios más baratos: [np.int64(680000), np.int64(475000), np.int64(860000), np.int64(430000), np.int64(719000), np.int64(470000), np.int64(399000), np.int64(825000), np.int64(358000), np.int64(595000), np.int64(475000), np.int64(870000)]
# - Chamartín:
#   Percentil 20: 1100000.00
#   Número de casas baratas: 11
#   Precios más baratos: [np.int64(950000), np.int64(575000), np.int64(370000), np.int64(475000), np.int64(350000), np.int64(420000), np.int64(730000), np.int64(630000), np.int64(790000), np.int64(830000), np.int64(560000)]
# - Cuatro Caminos:
#   Percentil 20: 358600.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(320000), np.int64(345000)]
# - Goya:
#   Percentil 20: 743200.00
#   Número de casas baratas: 5
#   Precios más baratos: [np.int64(649000), np.int64(315000), np.int64(685000), np.int64(719000), np.int64(650000)]
# - Aravaca:
#   Percentil 20: 902040.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(675000)]
# - Sol:
#   Percentil 20: 642000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(350000), np.int64(450000)]
# - Bernabéu-Hispanoamérica:
#   Percentil 20: 1037000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(995000), np.int64(790000)]
# - Vallehermoso:
#   Percentil 20: 890000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(890000), np.int64(745000)]
# - Huertas-Cortes:
#   Percentil 20: 734000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(650000), np.int64(425000)]
# - Chamberí:
#   Percentil 20: 829600.00
#   Número de casas baratas: 7
#   Precios más baratos: [np.int64(795000), np.int64(799000), np.int64(390000), np.int64(380000), np.int64(649000), np.int64(700000), np.int64(720000)]
# - Nueva España:
#   Percentil 20: 996000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(730000), np.int64(670000)]
# - Conde Orgaz-Piovera:
#   Percentil 20: 1650000.00
#   Número de casas baratas: 3
#   Precios más baratos: [np.int64(1650000), np.int64(525000), np.int64(1650000)]
# - Chueca-Justicia:
#   Percentil 20: 374400.00
#   Número de casas baratas: 4
#   Precios más baratos: [np.int64(330000), np.int64(199000), np.int64(250000), np.int64(299000)]
# - Argüelles:
#   Percentil 20: 460000.00
#   Número de casas baratas: 3
#   Precios más baratos: [np.int64(435000), np.int64(435000), np.int64(375000)]
# - Nuevos Ministerios-Ríos Rosas:
#   Percentil 20: 676600.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(560000), np.int64(595000)]
# - Centro:
#   Percentil 20: 556000.00
#   Número de casas baratas: 10
#   Precios más baratos: [np.int64(529900), np.int64(515000), np.int64(550000), np.int64(529900), np.int64(345000), np.int64(260000), np.int64(309000), np.int64(520000), np.int64(495000), np.int64(500000)]
# - Moncloa:
#   Percentil 20: 909000.00
#   Número de casas baratas: 10
#   Precios más baratos: [np.int64(875000), np.int64(840000), np.int64(640000), np.int64(720000), np.int64(895000), np.int64(750000), np.int64(595000), np.int64(349000), np.int64(835000), np.int64(795000)]
# - Retiro:
#   Percentil 20: 670000.00
#   Número de casas baratas: 6
#   Precios más baratos: [np.int64(557000), np.int64(599000), np.int64(670000), np.int64(660000), np.int64(670000), np.int64(635000)]
# - Barrio de Salamanca:
#   Percentil 20: 803400.00
#   Número de casas baratas: 13
#   Precios más baratos: [np.int64(698000), np.int64(750000), np.int64(715000), np.int64(780000), np.int64(680000), np.int64(799000), np.int64(698000), np.int64(780000), np.int64(720000), np.int64(698000), np.int64(560000), np.int64(725000), np.int64(799000)]
# - Peñagrande:
#   Percentil 20: 782800.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(480000)]
# - Mirasierra:
#   Percentil 20: 1625000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(1625000), np.int64(1625000)]
# - Fuencarral:
#   Percentil 20: 650000.00
#   Número de casas baratas: 8
#   Precios más baratos: [np.int64(470000), np.int64(535000), np.int64(460000), np.int64(485000), np.int64(650000), np.int64(430000), np.int64(415000), np.int64(650000)]
# - Comillas:
#   Percentil 20: 475000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(475000)]
# - Malasaña-Universidad:
#   Percentil 20: 538200.00
#   Número de casas baratas: 5
#   Precios más baratos: [np.int64(330000), np.int64(499000), np.int64(464000), np.int64(299000), np.int64(240000)]
# - Palos de Moguer:
#   Percentil 20: 438000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(380000)]
# - San Blas:
#   Percentil 20: 646000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(535000), np.int64(375000)]
# - Prosperidad:
#   Percentil 20: 405200.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(290000), np.int64(399000)]
# - Bellas Vistas:
#   Percentil 20: 325000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(325000)]
# - Niño Jesús:
#   Percentil 20: 930000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(550000)]
# - El Viso:
#   Percentil 20: 1060600.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(675000), np.int64(785000)]
# - Palacio:
#   Percentil 20: 410000.00
#   Número de casas baratas: 3
#   Precios más baratos: [np.int64(320000), np.int64(267000), np.int64(375000)]
# - Lista:
#   Percentil 20: 682800.00
#   Número de casas baratas: 5
#   Precios más baratos: [np.int64(675000), np.int64(569000), np.int64(550000), np.int64(679000), np.int64(550000)]
# - Ciudad Lineal:
#   Percentil 20: 809200.00
#   Número de casas baratas: 5
#   Precios más baratos: [np.int64(233000), np.int64(350000), np.int64(799000), np.int64(500000), np.int64(730000)]
# - Lavapiés-Embajadores:
#   Percentil 20: 258000.00
#   Número de casas baratas: 4
#   Precios más baratos: [np.int64(238000), np.int64(150000), np.int64(160000), np.int64(235000)]
# - Salvador:
#   Percentil 20: 538920.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(379900)]
# - Almagro:
#   Percentil 20: 1452000.00
#   Número de casas baratas: 4
#   Precios más baratos: [np.int64(1049000), np.int64(950000), np.int64(1380000), np.int64(750000)]
# - Fuente del Berro:
#   Percentil 20: 515000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(399000), np.int64(515000)]
# - Gaztambide:
#   Percentil 20: 641000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(425000), np.int64(445000)]
# - Acacias:
#   Percentil 20: 353800.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(169000)]
# - Arapiles:
#   Percentil 20: 349000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(319000), np.int64(349000)]
# - Guindalera:
#   Percentil 20: 410000.00
#   Número de casas baratas: 4
#   Precios más baratos: [np.int64(410000), np.int64(250000), np.int64(410000), np.int64(299000)]
# - Ciudad Universitaria:
#   Percentil 20: 960000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(870000), np.int64(369000)]
# - Puerta del Ángel:
#   Percentil 20: 454600.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(199000)]
# - Ventilla-Almenara:
#   Percentil 20: 910000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(910000), np.int64(910000)]
# - Rejas:
#   Percentil 20: 281800.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(262500)]
# - Pau de Carabanchel:
#   Percentil 20: 378000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(378000)]
# - Zofío:
#   Percentil 20: 164000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(164000)]
# - La Paz:
#   Percentil 20: 470200.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(439000)]
# - Valdezarza:
#   Percentil 20: 427000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(385000)]
# - Pacífico:
#   Percentil 20: 374000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(370000)]
# - Costillares:
#   Percentil 20: 395600.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(299000)]
# - Trafalgar:
#   Percentil 20: 653000.00
#   Número de casas baratas: 3
#   Precios más baratos: [np.int64(338000), np.int64(565000), np.int64(308000)]
# - Simancas:
#   Percentil 20: 159580.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(132000), np.int64(122000)]
# - Ibiza:
#   Percentil 20: 669400.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(530000), np.int64(625000)]
# - Jerónimos:
#   Percentil 20: 897400.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(550000)]
# - Legazpi:
#   Percentil 20: 1250000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(1250000)]
# - Palomas:
#   Percentil 20: 665000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(470000)]
# - Castilla:
#   Percentil 20: 776630.80
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(442327)]
# - Pinar del Rey:
#   Percentil 20: 345000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(345000)]
# - Cuzco-Castillejos:
#   Percentil 20: 950000.00
#   Número de casas baratas: 3
#   Precios más baratos: [np.int64(369000), np.int64(950000), np.int64(950000)]
# - San Isidro:
#   Percentil 20: 193400.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(140000)]
# - Opañel:
#   Percentil 20: 260000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(260000)]
# - Colina:
#   Percentil 20: 329900.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(329900), np.int64(329900)]
# - El Cañaveral:
#   Percentil 20: 648000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(648000)]
# - Valdemarín:
#   Percentil 20: 1103280.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(1038800)]
# - Tetuán:
#   Percentil 20: 918000.00
#   Número de casas baratas: 2
#   Precios más baratos: [np.int64(675000), np.int64(585000)]
# - Valdeacederas:
#   Percentil 20: 388000.00
#   Número de casas baratas: 4
#   Precios más baratos: [np.int64(260000), np.int64(349000), np.int64(388000), np.int64(388000)]
# - Valdebebas - Valdefuentes:
#   Percentil 20: 746760.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(735000)]
# - Almendrales:
#   Percentil 20: 182600.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(169000)]
# - Canillas:
#   Percentil 20: 336000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(210000)]
# - Imperial:
#   Percentil 20: 357000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(245000)]
# - Sanchinarro:
#   Percentil 20: 555000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(555000)]
# - Berruguete:
#   Percentil 20: 291600.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(279000)]
# - Concepción:
#   Percentil 20: 365900.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(365900)]
# - Quintana:
#   Percentil 20: 253540.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(249900)]
# - Pueblo Nuevo:
#   Percentil 20: 220900.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(214900)]
# - Los Ángeles:
#   Percentil 20: 175800.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(145000)]
# - Ensanche de Vallecas - La Gavia:
#   Percentil 20: 179000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(179000)]
# - San Diego:
#   Percentil 20: 136000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(125000)]
# - Butarque:
#   Percentil 20: 265000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(265000)]
# - Campamento:
#   Percentil 20: 388000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(388000)]
# - Ciudad Jardín:
#   Percentil 20: 1003000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(345000)]
# - Estrella:
#   Percentil 20: 525940.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(499900)]
# - Vista Alegre:
#   Percentil 20: 171980.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(155000)]
# - Barajas:
#   Percentil 20: 281600.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(270000)]
# - Ventas:
#   Percentil 20: 173600.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(137000)]
# - Timón:
#   Percentil 20: 368400.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(253000)]
# - Virgen del Cortijo - Manoteras:
#   Percentil 20: 899000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(899000)]
# - 12 de Octubre-Orcasur:
#   Percentil 20: 155000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(155000)]
# - Puente de Vallecas:
#   Percentil 20: 216000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(210000)]
# - Moratalaz:
#   Percentil 20: 300000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(300000)]
# - Fuentelarreina:
#   Percentil 20: 960000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(875000)]
# - Amposta:
#   Percentil 20: 255900.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(255900)]
# - Latina:
#   Percentil 20: 270000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(270000)]
# - Delicias:
#   Percentil 20: 569000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(569000)]
# - San Fermín:
#   Percentil 20: 179000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(179000)]
# - Buena Vista:
#   Percentil 20: 230000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(230000)]
# - Casco Histórico de Barajas:
#   Percentil 20: 485000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(485000)]
# - Chopera:
#   Percentil 20: 318000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(310000)]
# - El Plantío:
#   Percentil 20: 1700000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(1700000)]
# - Arganzuela:
#   Percentil 20: 850000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(850000)]
# - Canillejas:
#   Percentil 20: 1950000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(1950000)]
# - San Juan Bautista:
#   Percentil 20: 1150000.00
#   Número de casas baratas: 1
#   Precios más baratos: [np.int64(1150000)]
# ------------------------------------------------
# Moda de las direcciones: [(np.str_('Barrio de Salamanca'), 63)]
# ------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 30
#      27 moda(addresses)
#      28 print("------------------------------------------------")
# ---> 30 variance, std_dev = varianza_desviacion(price)
#      31 print("------------------------------------------------")
#      33 upper_limit, lower_limit, outliers = filtro_outliers_tukey(price, q1, q3, iqr)
#
# NameError: name 'varianza_desviacion' is not defined
